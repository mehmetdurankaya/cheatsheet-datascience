# %% [markdown]
# # Birleştirme (Join) işlemleri

# %%
import numpy as np
import pandas as pd
m=np.random.randint(1,30,size=(5,3))
df1 = pd.DataFrame(m,columns=["var1","var2","var3"])

# %%
df1
# Out:
#    var1  var2  var3
# 0    26    12    16
# 1     8    15    11
# 2    24    24     2
# 3    14    24    20
# 4    17    25    11

# %%
df2=df1+99

# %%
df2
# Out:
#    var1  var2  var3
# 0   125   111   115
# 1   107   114   110
# 2   123   123   101
# 3   113   123   119
# 4   116   124   110

# %%
pd.concat([df1,df2])
# Out:
#    var1  var2  var3
# 0    26    12    16
# 1     8    15    11
# 2    24    24     2
# 3    14    24    20
# 4    17    25    11
# 0   125   111   115
# 1   107   114   110
# 2   123   123   101
# 3   113   123   119
# 4   116   124   110

# %%
# ?pd.concat  #DataFrame leri birleştirdim ancak indexlerde sorun var nasıl çözebilirim
# Out:
# Signature:
# pd.concat(
#     objs: 'Iterable[NDFrame] | Mapping[HashableT, NDFrame]',
#     *,
#     axis: 'Axis' = 0,
#     join: 'str' = 'outer',
#     ignore_index: 'bool' = False,
#     keys=None,
#     levels=None,
#     names=None,
#     verify_integrity: 'bool' = False,
#     sort: 'bool' = False,
#     copy: 'bool | None' = None,
# ) -> 'DataFrame | Series'
# Docstring:
# Concatenate pandas objects along a particular axis.
#
# Allows optional set logic along the other axes.
#
# Can also add a layer of hierarchical indexing on the concatenation axis,
# which may be useful if the labels are the same (or overlapping) on
# the passed axis number.
#
# Parameters
# ----------
# objs : a sequence or mapping of Series or DataFrame objects
#     If a mapping is passed, the sorted keys will be used as the `keys`
#     argument, unless it is passed, in which case the values will be
#     selected (see below). Any None objects will be dropped silently unless
# ...

# %%
pd.concat([df1,df2],ignore_index=True) # birleştirme sonrasında index sorun çözüldü
# Out:
#    var1  var2  var3
# 0    26    12    16
# 1     8    15    11
# 2    24    24     2
# 3    14    24    20
# 4    17    25    11
# 5   125   111   115
# 6   107   114   110
# 7   123   123   101
# 8   113   123   119
# 9   116   124   110

# %%
df1.columns
# Out:
# Index(['var1', 'var2', 'var3'], dtype='object')

# %%
df2.columns
# Out:
# Index(['var1', 'var2', 'var3'], dtype='object')

# %%
df2.columns=("var1","var2","deg3")

# %%
df2
# Out:
#    var1  var2  deg3
# 0   125   111   115
# 1   107   114   110
# 2   123   123   101
# 3   113   123   119
# 4   116   124   110

# %%
df1
# Out:
#    var1  var2  var3
# 0    26    12    16
# 1     8    15    11
# 2    24    24     2
# 3    14    24    20
# 4    17    25    11

# %%
pd.concat([df1,df2],join="inner",ignore_index=True)
# Out:
#    var1  var2
# 0    26    12
# 1     8    15
# 2    24    24
# 3    14    24
# 4    17    25
# 5   125   111
# 6   107   114
# 7   123   123
# 8   113   123
# 9   116   124

# %%
df1=pd.DataFrame({'calisanlar':['Ali','Veli','Ayse','Fatma'],
                 'grup':['Muhasebe','Muhendislik','Muhendislik','İK']})

# %%
df1
# Out:
#   calisanlar         grup
# 0        Ali     Muhasebe
# 1       Veli  Muhendislik
# 2       Ayse  Muhendislik
# 3      Fatma           İK

# %%
df2=pd.DataFrame({'calisanlar':['Ayse','Ali','Veli','Fatma'],
                 'ilk_giris':[2010,2009,2014,2019]})

# %%
df2
# Out:
#   calisanlar  ilk_giris
# 0       Ayse       2010
# 1        Ali       2009
# 2       Veli       2014
# 3      Fatma       2019

# %%
pd.merge(df1,df2)
# Out:
#   calisanlar         grup  ilk_giris
# 0        Ali     Muhasebe       2009
# 1       Veli  Muhendislik       2014
# 2       Ayse  Muhendislik       2010
# 3      Fatma           İK       2019

# %%
pd.merge(df1,df2, on="calisanlar")
# Out:
#   calisanlar         grup  ilk_giris
# 0        Ali     Muhasebe       2009
# 1       Veli  Muhendislik       2014
# 2       Ayse  Muhendislik       2010
# 3      Fatma           İK       2019

# %%
#çoktan teke

# %%
df3=pd.merge(df1,df2)

# %%
df3
# Out:
#   calisanlar         grup  ilk_giris
# 0        Ali     Muhasebe       2009
# 1       Veli  Muhendislik       2014
# 2       Ayse  Muhendislik       2010
# 3      Fatma           İK       2019

# %%
df4=pd.DataFrame({'grup':['Muhasebe','Muhendislik','İK'],
                 'mudur':['Caner','Mustafa','Berkcan']})

# %%
df4
# Out:
#           grup    mudur
# 0     Muhasebe    Caner
# 1  Muhendislik  Mustafa
# 2           İK  Berkcan

# %%
pd.merge(df3,df4)
# Out:
#   calisanlar         grup  ilk_giris    mudur
# 0        Ali     Muhasebe       2009    Caner
# 1       Veli  Muhendislik       2014  Mustafa
# 2       Ayse  Muhendislik       2010  Mustafa
# 3      Fatma           İK       2019  Berkcan

# %%
# Çoktan çoka

# %%
df5=pd.DataFrame({'grup':['Muhasebe','Muhasebe',
                         'Mühendislik','Mühendislik','İK','İK',],
                 'yetenekler':['matematik','excel','kodlama','linux','excel','yonetim']})

# %%
df5
# Out:
#           grup yetenekler
# 0     Muhasebe  matematik
# 1     Muhasebe      excel
# 2  Mühendislik    kodlama
# 3  Mühendislik      linux
# 4           İK      excel
# 5           İK    yonetim

# %%
pd.merge(df1,df5)
# Out:
#   calisanlar      grup yetenekler
# 0        Ali  Muhasebe  matematik
# 1        Ali  Muhasebe      excel
# 2      Fatma        İK      excel
# 3      Fatma        İK    yonetim
